# %% [markdown]
# # Evidencia de la Kata 2

# %%
# %pip install Matplotlib
# %pip install Ipython.Display
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 21.2.4; however, version 22.0.3 is available.
# You should consider upgrading via the 'C:\Users\thela\AppData\Local\Programs\Python\Python310\python.exe -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not find a version that satisfies the requirement Ipython.Display (from versions: none)
# ERROR: No matching distribution found for Ipython.Display
# WARNING: You are using pip version 21.2.4; however, version 22.0.3 is available.
# You should consider upgrading via the 'C:\Users\thela\AppData\Local\Programs\Python\Python310\python.exe -m pip install --upgrade pip' command.

# %%
import IPython.display as display
from PIL import Image
display.display(Image.open('evidencia.png'))
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1107x946 at 0x1BC1051AD70>
